# %%
import cv2
from matplotlib import pyplot as plt

# !wget "https://www.labmedya.com/uploads/haberler-3/kedi.jpg"
# Out:
# --2023-03-21 14:18:33--  https://www.labmedya.com/uploads/haberler-3/kedi.jpg
# Resolving www.labmedya.com (www.labmedya.com)... 136.243.7.161
# Connecting to www.labmedya.com (www.labmedya.com)|136.243.7.161|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55219 (54K) [image/jpeg]
# Saving to: ‘kedi.jpg’
#
# kedi.jpg            100%[===================>]  53.92K   358KB/s    in 0.2s
#
# 2023-03-21 14:18:34 (358 KB/s) - ‘kedi.jpg’ saved [55219/55219]

# %%
BGR_img = cv2.imread('kedi.jpg')
print(BGR_img.shape)

RGB_img = cv2.cvtColor(BGR_img, cv2.COLOR_BGR2RGB)

plt.imshow(RGB_img)
plt.show()
# Out:
# (800, 1200, 3)
