# %%
# !wget "https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEi4kn9mtwyzYOduAlYxUSuJv7hV5aDhQqpQmCEuu93AK9dHCjclzIz-AoF0wtvtT0Ojck-9XredP0UAx0fC8FKYoKV8Rs4Lder-M4jhYvK4OjpQa6lRo3s33RS3l51eWd3jZNimIFZ0uIP7m6-umA36AUCC--dADghpnGT02qqlvLRQ2BWgDgFJmRSQHw/s256/rice.png"
# Out:
# --2023-04-10 11:55:53--  https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEi4kn9mtwyzYOduAlYxUSuJv7hV5aDhQqpQmCEuu93AK9dHCjclzIz-AoF0wtvtT0Ojck-9XredP0UAx0fC8FKYoKV8Rs4Lder-M4jhYvK4OjpQa6lRo3s33RS3l51eWd3jZNimIFZ0uIP7m6-umA36AUCC--dADghpnGT02qqlvLRQ2BWgDgFJmRSQHw/s256/rice.png
# Resolving blogger.googleusercontent.com (blogger.googleusercontent.com)... 64.233.191.132, 2607:f8b0:4001:c0c::84
# Connecting to blogger.googleusercontent.com (blogger.googleusercontent.com)|64.233.191.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44622 (44K) [image/png]
# Saving to: ‘rice.png.2’
#
# rice.png.2          100%[===================>]  43.58K  --.-KB/s    in 0.002s
#
# 2023-04-10 11:55:53 (20.3 MB/s) - ‘rice.png.2’ saved [44622/44622]

# %%
import cv2
from matplotlib import pyplot as plt

rice = cv2.imread("rice.png")

# %%
gray = cv2.cvtColor(rice, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap = "gray")
plt.show()

# %%
ret, thresh = cv2.threshold(gray, 120, 255, cv2.THRESH_BINARY)
plt.imshow(thresh, cmap = 'gray')
plt.show()

# %%
import numpy as np
kernel = np.ones((3, 3), np.uint8)
img_erosion = cv2.erode(thresh, kernel)
img_dilation = cv2.dilate(thresh, kernel)

plt.imshow(img_erosion , cmap = 'gray')
plt.show()

plt.imshow(img_dilation , cmap = 'gray')
plt.show()
